# %%
import pandas as pd

# Load your sample data
df = pd.read_csv("../data/sample.csv")

# Basic info
print("Initial DataFrame:")
print(df.head())

# Example of adding a new column
df["double_y"] = df["y"] * 2

# Check for missing values
print("\nMissing values:")
print(df.isnull().sum())

# Summary statistics
print("\nSummary statistics:")
print(df.describe())
# Out:
# Initial DataFrame:
#    x  y
# 0  1  2
# 1  2  4
# 2  3  6
# 3  4  8
#
# Missing values:
# x           0
# y           0
# double_y    0
# dtype: int64
#
# Summary statistics:
#               x         y   double_y
# count  4.000000  4.000000   4.000000
# mean   2.500000  5.000000  10.000000
# std    1.290994  2.581989   5.163978
# min    1.000000  2.000000   4.000000
# 25%    1.750000  3.500000   7.000000
# 50%    2.500000  5.000000  10.000000
# 75%    3.250000  6.500000  13.000000
# max    4.000000  8.000000  16.000000
